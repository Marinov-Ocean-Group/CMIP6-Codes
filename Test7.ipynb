# %%
from dask.distributed import Client, progress
from dask_kubernetes import KubeCluster
cluster = KubeCluster()
cluster.adapt(maximum=30)
cluster
# Out:
# VBox(children=(HTML(value='<h2>KubeCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .…

# %%
client = Client(cluster)
client
# Out:
# <Client: 'tcp://10.32.12.80:43727' processes=4 threads=8, memory=46.00 GB>

# %%
import os
os.environ['NUMPY_EXPERIMENTAL_ARRAY_FUNCTION'] = '0'

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import gcsfs
import gsw
from tqdm.autonotebook import tqdm
import cartopy.crs as ccrs
import cartopy
import xesmf as xe

from xhistogram.xarray import histogram

# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 6
# %config InlineBackend.figure_format = 'retina'
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tqdm/autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
def Catalog_filter(catalog, var, ense, exp, freq):
    '''
    Function that takes LISTS of:
    var = desired variable name
    ense = desired ensembles
    exp = deisred epxeriments
    freq = desired sample rate (frequency)
    and returns list of model names and filtered catalog
    '''
    
    # Creates a new dataframe based on the filters
    df_filter = catalog[(catalog['experiment_id'].isin(exp)) & \
          (catalog['table_id'].isin(freq)) & \
         (catalog['member_id'].isin(ense)) & \
         (catalog['variable_id'].isin(var))]
    
    models = df_filter.source_id.unique()
    
    return models, df_filter
 
    
def get_data(df, variable, model):
    '''
    Function that downloads variable data from google-cloud
    and returns xarray dataset with all the variable data
    
    IMPORANT - variables in list should have same dimensions!!!
    '''
    
    ds_l = []
    for var in variable:
        uri = df[(df.variable_id == var) & 
                (df.source_id == model)].zstore.values[0]
        gcs = gcsfs.GCSFileSystem(token='anon')
        ds = xr.open_zarr(gcs.get_mapper(uri), consolidated=True)
        ds_l.append(ds)
        
    ds_full = xr.merge(ds_l)
    return ds_full

# %%
df = pd.read_csv('https://storage.googleapis.com/pangeo-cmip6/pangeo-cmip6-zarr-consolidated-stores.csv')
df

variable_ids = ['so', 'thetao']
experiment_ids = ['historical']
table_ids = ['Omon']
member_ids = ['r1i1p1f1']

source_list, df2 = Catalog_filter(df, variable_ids, 
                                  member_ids, experiment_ids,
                                  table_ids)

xrays = []
 
for source in tqdm(source_list[1:5]):
    xray = get_data(df2, variable_ids, source)
    xrays.append(xray)
    
xray_dic = {key:value for key, value in zip(source_list, xrays)}
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))

# %%
def url_to_xray(urls_l):
    '''
    Function that takes urls for ONE VARIABLE and returns
    a concatenated xarray 
    '''
    
    xrays = []
    
    for key in tqdm(urls_l):
        xray = xr.open_dataset(urls_l[key], decode_times=False)
        xrays.append(xray)
        
    xrays_f = xr.concat(xrays, dim='time')
    
    return xrays_f


urls_T = {'WOA_T_85_94': 'https://data.nodc.noaa.gov/thredds/dodsC/ncei/woa/temperature/8594/1.00/woa18_8594_t00_01.nc',
          'WOA_T_95_04': 'https://data.nodc.noaa.gov/thredds/dodsC/ncei/woa/temperature/95A4/1.00/woa18_95A4_t00_01.nc'
          }
          
urls_S = {'WOA_S_85-94': 'https://data.nodc.noaa.gov/thredds/dodsC/ncei/woa/salinity/8594/1.00/woa18_8594_s00_01.nc',
          'WOA_S_95-04': 'https://data.nodc.noaa.gov/thredds/dodsC/ncei/woa/salinity/95A4/1.00/woa18_95A4_s00_01.nc'
          }


xr_obs_T = url_to_xray(urls_T)
xr_obs_S = url_to_xray(urls_S)
xr_obs_full = xr.merge([xr_obs_T, xr_obs_S])
xr_obs_full
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# <xarray.Dataset>
# Dimensions:             (depth: 102, lat: 180, lon: 360, nbounds: 2, time: 2)
# Coordinates:
#   * lat                 (lat) float32 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * depth               (depth) float32 0.0 5.0 10.0 ... 5300.0 5400.0 5500.0
#   * lon                 (lon) float32 -179.5 -178.5 -177.5 ... 177.5 178.5 179.5
#   * time                (time) float64 438.0 438.0
# Dimensions without coordinates: nbounds
# Data variables:
#     crs                 (time) int32 -2147483647 -2147483647
#     lat_bnds            (time, lat, nbounds) float32 -90.0 -89.0 ... 89.0 90.0
#     lon_bnds            (time, lon, nbounds) float32 -180.0 -179.0 ... 180.0
#     depth_bnds          (time, depth, nbounds) float32 0.0 2.5 ... 5450.0 5500.0
#     climatology_bounds  (time, nbounds) float32 384.0 504.0 384.0 504.0
#     t_an                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     t_mn                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     t_dd                (time, depth, lat, lon) float64 nan nan nan ... nan nan
#     t_sd                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     t_se                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     t_oa                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     t_gp                (time, depth, lat, lon) float64 nan nan nan ... nan nan
#     s_an                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     s_mn                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     s_dd                (time, depth, lat, lon) float64 nan nan nan ... nan nan
#     s_sd                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     s_se                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     s_oa                (time, depth, lat, lon) float32 nan nan nan ... nan nan
#     s_gp                (time, depth, lat, lon) float64 nan nan nan ... nan nan

# %%
def create_pressure(data, var):
    '''
    Creates new pressure array from depth and latitudes using TEOS-10
    Input: xarray
    Output: xarray with pressure as new variable
    '''  
    z = -1*xr_obs_full.depth
    p = np.zeros((len(data.depth),len(data.lat)))

    for i in range(len(data.lat)):
        p[:,i] = gsw.p_from_z(z, data.lat[i])

    b = np.repeat(p[:, :, np.newaxis], len(data.lon), axis=2)

    P = np.empty_like(data[var])
    
    for i in range(P.shape[0]):
        P[i,:,:,:] = b
    
    xray = xr.DataArray(P, 
                        coords=xr_obs_full[var].coords, 
                        dims=xr_obs_full[var].dims,
                        name ='Pressure')
    data2 = xr.merge([data, xray])
    
    return data2



par = 't_an'
ds = create_pressure(xr_obs_full, par)

# %%
xray_dic.keys()
# Out:
# dict_keys(['AWI-CM-1-1-MR', 'BCC-CSM2-MR', 'BCC-ESM1', 'CAMS-CSM1-0'])

# %%
def Regridding(data, grid_out):

    grid_11 = xr.Dataset({'lat': (grid_out.lat), 'lon': (grid_out.lon)})
    regrid = xe.Regridder(data, grid_11, 
                      'bilinear', periodic=True, reuse_weights=True)
    return regrid(data)


S = xray_dic['BCC-CSM2-MR'].sel(time=slice('1986','2005')).mean(dim='time').mean(dim='lev').so

ds_plt = Regridding(S, ds)
ds_plt.to_netcdf('Shit.nc')

fig = plt.figure(figsize=(12,20))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines()
ax.gridlines()
S.plot(ax = ax, transform=ccrs.PlateCarree())
# Out:
# distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/core.py", line 44, in dumps
#     for key, value in data.items()
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/core.py", line 45, in <dictcomp>
#     if type(value) is Serialize
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 167, in serialize
#     for obj in x
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 167, in <listcomp>
#     for obj in x
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 210, in serialize
#     raise TypeError(msg, str(x)[:10000])
# TypeError: ('Could not serialize object of type SubgraphCallable.', 'subgraph_callable')
# distributed.comm.utils - ERROR - ('Could not serialize object of type SubgraphCallable.', 'subgraph_callable')
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/comm/utils.py", line 29, in _to_frames
#     msg, serializers=serializers, on_error=on_error, context=context
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/core.py", line 44, in dumps
#     for key, value in data.items()
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/core.py", line 45, in <dictcomp>
#     if type(value) is Serialize
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 167, in serialize
#     for obj in x
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 167, in <listcomp>
#     for obj in x
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 210, in serialize
#     raise TypeError(msg, str(x)[:10000])
# TypeError: ('Could not serialize object of type SubgraphCallable.', 'subgraph_callable')
# distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/batched.py", line 93, in _background_send
#     payload, serializers=self.serializers, on_error="raise"
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/comm/tcp.py", line 227, in write
#     context={"sender": self._local_addr, "recipient": self._peer_addr},
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/comm/utils.py", line 37, in to_frames
#     res = yield offload(_to_frames)
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/utils.py", line 1370, in offload
#     return (yield _offload_executor.submit(fn, *args, **kwargs))
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/srv/conda/envs/notebook/lib/python3.7/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/srv/conda/envs/notebook/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
#   File "/srv/conda/envs/notebook/lib/python3.7/concurrent/futures/thread.py", line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/comm/utils.py", line 29, in _to_frames
#     msg, serializers=serializers, on_error=on_error, context=context
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/core.py", line 44, in dumps
#     for key, value in data.items()
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/core.py", line 45, in <dictcomp>
#     if type(value) is Serialize
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 167, in serialize
#     for obj in x
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 167, in <listcomp>
#     for obj in x
#   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/protocol/serialize.py", line 210, in serialize
#     raise TypeError(msg, str(x)[:10000])
# TypeError: ('Could not serialize object of type SubgraphCallable.', 'subgraph_callable')
# Reuse existing file: bilinear_232x360_180x360_peri.nc

# %%
def Regridding(data, grid_out):

    grid_11 = xr.Dataset({'lat': (grid_out.lat), 'lon': (grid_out.lon)})
    regrid = xe.Regridder(data, grid_11, 
                      'bilinear', periodic=True, reuse_weights=True)
    return regrid(data)

ds_plt = Regridding(xray_dic['BCC-CSM2-MR'], ds)

S = ds_plt.sel(time=slice('1986','1990')).mean(dim='time').mean(dim='lev').so
# Out:
# Reuse existing file: bilinear_232x360_180x360_peri.nc
# using dimensions ('lat', 'lon') from data variable so as the horizontal dimensions for this dataset.

# %%
fig = plt.figure(figsize=(12,20))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines()
ax.gridlines()
S.plot(ax = ax, transform=ccrs.PlateCarree())

# %%
f.shape
# Out:
# (2, 102, 180, 360)

# %%
xrays[0]['so'].lat.values
# Out:
# array([-47.39407752, -48.47549908, -49.20522144, ...,  59.96596739,
#         33.4582047 ,  42.16660379])

# %%
#Taking Monthly Ocean data (Omon), for Salinity (so) and Potential Temperature (thetao)
variable_ids = ['so', 'thetao']
experiment_ids = ['historical']
table_ids = ['Omon']
member_ids = ['r1i1p1f1']
source_ids = []

for name, group in df.groupby('source_id'):
    if (all([expt in group.experiment_id.values
            for expt in experiment_ids]) and
        all([expt in group.variable_id.values
            for expt in variable_ids]) and
       all([expt in group.table_id.values
            for expt in table_ids]) and
       all([expt in group.member_id.values
            for expt in member_ids])):
        source_ids.append(name)

source_ids # Models with both monthly potential T and S
# Out:
# ['AWI-CM-1-1-MR',
#  'BCC-CSM2-MR',
#  'BCC-ESM1',
#  'CAMS-CSM1-0',
#  'CESM2',
#  'CESM2-WACCM',
#  'CanESM5',
#  'E3SM-1-0',
#  'EC-Earth3',
#  'EC-Earth3-Veg',
#  'FGOALS-f3-L',
#  'GFDL-CM4',
#  'GFDL-ESM4',
#  'GISS-E2-1-G',
#  'GISS-E2-1-G-CC',
#  'GISS-E2-1-H',
#  'HadGEM3-GC31-LL',
#  'IPSL-CM6A-LR',
#  'MCM-UA-1-0',
#  'MIROC6',
#  'NESM3',
#  'NorCPM1',
#  'SAM0-UNICON']

# %%
len(df_S.source_id.unique())
# Out:
# 15

# %%
len(df_S.source_id.unique())
# Out:
# 27

# %%
df_T
# Out:
#       activity_id       institution_id       source_id experiment_id  \
# 169          CMIP                  AWI   AWI-CM-1-1-MR    historical
# 325          CMIP                  BCC     BCC-CSM2-MR    historical
# 588          CMIP                  BCC        BCC-ESM1    historical
# 841          CMIP                 CAMS     CAMS-CSM1-0    historical
# 904          CMIP                  CAS     FGOALS-f3-L    historical
# 5759         CMIP         E3SM-Project        E3SM-1-0    historical
# 6034         CMIP  EC-Earth-Consortium   EC-Earth3-Veg    historical
# 11497        CMIP            NASA-GISS  GISS-E2-1-G-CC    historical
# 13388        CMIP                 NCAR     CESM2-WACCM    historical
# 14583        CMIP                 NCAR           CESM2    historical
# 14584        CMIP                 NCAR           CESM2    historical
# 16522        CMIP            NOAA-GFDL        GFDL-CM4    historical
# 16523        CMIP            NOAA-GFDL        GFDL-CM4    historical
# 16704        CMIP            NOAA-GFDL       GFDL-ESM4    historical
# 16705        CMIP            NOAA-GFDL       GFDL-ESM4    historical
# 16841        CMIP                NUIST           NESM3    historical
# 17096        CMIP                  SNU     SAM0-UNICON    historical
# 17215        CMIP                   UA      MCM-UA-1-0    historical
#
#       member_id table_id variable_id grid_label  \
# 169    r1i1p1f1     Omon      thetao         gn
# 325    r1i1p1f1     Omon      thetao         gn
# 588    r1i1p1f1     Omon      thetao         gn
# 841    r1i1p1f1     Omon      thetao         gn
# 904    r1i1p1f1     Omon      thetao         gn
# 5759   r1i1p1f1     Omon      thetao         gr
# 6034   r1i1p1f1     Omon      thetao         gn
# 11497  r1i1p1f1     Omon      thetao         gn
# 13388  r1i1p1f1     Omon      thetao         gr
# 14583  r1i1p1f1     Omon      thetao         gn
# 14584  r1i1p1f1     Omon      thetao         gr
# 16522  r1i1p1f1     Omon      thetao         gn
# 16523  r1i1p1f1     Omon      thetao         gr
# 16704  r1i1p1f1     Omon      thetao         gn
# 16705  r1i1p1f1     Omon      thetao         gr
# 16841  r1i1p1f1     Omon      thetao         gn
# 17096  r1i1p1f1     Omon      thetao         gn
# 17215  r1i1p1f1     Omon      thetao         gn
#
#                                                   zstore  dcpp_init_year
# 169    gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 325    gs://cmip6/CMIP/BCC/BCC-CSM2-MR/historical/r1i...             NaN
# 588    gs://cmip6/CMIP/BCC/BCC-ESM1/historical/r1i1p1...             NaN
# 841    gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/historical/r1...             NaN
# 904    gs://cmip6/CMIP/CAS/FGOALS-f3-L/historical/r1i...             NaN
# 5759   gs://cmip6/CMIP/E3SM-Project/E3SM-1-0/historic...             NaN
# 6034   gs://cmip6/CMIP/EC-Earth-Consortium/EC-Earth3-...             NaN
# 11497  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G-CC/histo...             NaN
# 13388  gs://cmip6/CMIP/NCAR/CESM2-WACCM/historical/r1...             NaN
# 14583  gs://cmip6/CMIP/NCAR/CESM2/historical/r1i1p1f1...             NaN
# 14584  gs://cmip6/CMIP/NCAR/CESM2/historical/r1i1p1f1...             NaN
# 16522  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/historical/...             NaN
# 16523  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/historical/...             NaN
# 16704  gs://cmip6/CMIP/NOAA-GFDL/GFDL-ESM4/historical...             NaN
# 16705  gs://cmip6/CMIP/NOAA-GFDL/GFDL-ESM4/historical...             NaN
# 16841  gs://cmip6/CMIP/NUIST/NESM3/historical/r1i1p1f...             NaN
# 17096  gs://cmip6/CMIP/SNU/SAM0-UNICON/historical/r1i...             NaN
# 17215  gs://cmip6/CMIP/UA/MCM-UA-1-0/historical/r1i1p...             NaN

# %%
df_S
# Out:
#       activity_id       institution_id        source_id experiment_id  \
# 165          CMIP                  AWI    AWI-CM-1-1-MR    historical
# 323          CMIP                  BCC      BCC-CSM2-MR    historical
# 586          CMIP                  BCC         BCC-ESM1    historical
# 838          CMIP                 CAMS      CAMS-CSM1-0    historical
# 903          CMIP                  CAS      FGOALS-f3-L    historical
# 1455         CMIP                CCCma          CanESM5    historical
# 4476         CMIP         CNRM-CERFACS       CNRM-CM6-1    historical
# 5411         CMIP         CNRM-CERFACS      CNRM-ESM2-1    historical
# 5755         CMIP         E3SM-Project         E3SM-1-0    historical
# 6030         CMIP  EC-Earth-Consortium    EC-Earth3-Veg    historical
# 6540         CMIP                 IPSL     IPSL-CM6A-LR    historical
# 9246         CMIP                MIROC       MIROC-ES2L    historical
# 9540         CMIP                MIROC           MIROC6    historical
# 10200        CMIP                 MOHC  HadGEM3-GC31-LL    historical
# 10498        CMIP                 MOHC      UKESM1-0-LL    historical
# 11493        CMIP            NASA-GISS   GISS-E2-1-G-CC    historical
# 11683        CMIP            NASA-GISS      GISS-E2-1-G    historical
# 11747        CMIP            NASA-GISS      GISS-E2-1-G    historical
# 12593        CMIP            NASA-GISS      GISS-E2-1-H    historical
# 13382        CMIP                 NCAR      CESM2-WACCM    historical
# 14236        CMIP                 NCAR            CESM2    historical
# 14237        CMIP                 NCAR            CESM2    historical
# 14412        CMIP                 NCAR            CESM2    historical
# 14413        CMIP                 NCAR            CESM2    historical
# 14577        CMIP                 NCAR            CESM2    historical
# 14578        CMIP                 NCAR            CESM2    historical
# 14742        CMIP                 NCAR            CESM2    historical
# 14743        CMIP                 NCAR            CESM2    historical
# 14907        CMIP                 NCAR            CESM2    historical
# 14908        CMIP                 NCAR            CESM2    historical
# 15072        CMIP                 NCAR            CESM2    historical
# 15073        CMIP                 NCAR            CESM2    historical
# 15236        CMIP                 NCAR            CESM2    historical
# 15237        CMIP                 NCAR            CESM2    historical
# 15401        CMIP                 NCAR            CESM2    historical
# 15402        CMIP                 NCAR            CESM2    historical
# 15565        CMIP                 NCAR            CESM2    historical
# 15566        CMIP                 NCAR            CESM2    historical
# 15729        CMIP                 NCAR            CESM2    historical
# 15730        CMIP                 NCAR            CESM2    historical
# 15893        CMIP                 NCAR            CESM2    historical
# 15894        CMIP                 NCAR            CESM2    historical
# 16230        CMIP                  NCC          NorCPM1    historical
# 16515        CMIP            NOAA-GFDL         GFDL-CM4    historical
# 16516        CMIP            NOAA-GFDL         GFDL-CM4    historical
# 16696        CMIP            NOAA-GFDL        GFDL-ESM4    historical
# 16697        CMIP            NOAA-GFDL        GFDL-ESM4    historical
# 16837        CMIP                NUIST            NESM3    historical
# 17092        CMIP                  SNU      SAM0-UNICON    historical
# 17211        CMIP                   UA       MCM-UA-1-0    historical
#
#         member_id table_id variable_id grid_label  \
# 165      r1i1p1f1     Omon          so         gn
# 323      r1i1p1f1     Omon          so         gn
# 586      r1i1p1f1     Omon          so         gn
# 838      r1i1p1f1     Omon          so         gn
# 903      r1i1p1f1     Omon          so         gn
# 1455    r10i1p1f1     Omon          so         gn
# 4476    r10i1p1f2     Omon          so         gn
# 5411     r2i1p1f2     Omon          so         gn
# 5755     r1i1p1f1     Omon          so         gr
# 6030     r1i1p1f1     Omon          so         gn
# 6540    r10i1p1f1     Omon          so         gn
# 9246     r1i1p1f2     Omon          so         gn
# 9540    r10i1p1f1     Omon          so         gn
# 10200    r2i1p1f3     Omon          so         gn
# 10498    r1i1p1f2     Omon          so         gn
# 11493    r1i1p1f1     Omon          so         gn
# 11683  r102i1p1f1     Omon          so         gn
# 11747   r10i1p1f1     Omon          so         gn
# 12593   r10i1p1f1     Omon          so         gr
# 13382    r1i1p1f1     Omon          so         gr
# 14236   r10i1p1f1     Omon          so         gn
# 14237   r10i1p1f1     Omon          so         gr
# 14412   r11i1p1f1     Omon          so         gn
# 14413   r11i1p1f1     Omon          so         gr
# 14577    r1i1p1f1     Omon          so         gn
# 14578    r1i1p1f1     Omon          so         gr
# 14742    r2i1p1f1     Omon          so         gn
# 14743    r2i1p1f1     Omon          so         gr
# 14907    r3i1p1f1     Omon          so         gn
# 14908    r3i1p1f1     Omon          so         gr
# 15072    r4i1p1f1     Omon          so         gn
# 15073    r4i1p1f1     Omon          so         gr
# 15236    r5i1p1f1     Omon          so         gn
# 15237    r5i1p1f1     Omon          so         gr
# 15401    r6i1p1f1     Omon          so         gn
# 15402    r6i1p1f1     Omon          so         gr
# 15565    r7i1p1f1     Omon          so         gn
# 15566    r7i1p1f1     Omon          so         gr
# 15729    r8i1p1f1     Omon          so         gn
# 15730    r8i1p1f1     Omon          so         gr
# 15893    r9i1p1f1     Omon          so         gn
# 15894    r9i1p1f1     Omon          so         gr
# 16230   r24i1p1f1     Omon          so         gr
# 16515    r1i1p1f1     Omon          so         gn
# 16516    r1i1p1f1     Omon          so         gr
# 16696    r1i1p1f1     Omon          so         gn
# 16697    r1i1p1f1     Omon          so         gr
# 16837    r1i1p1f1     Omon          so         gn
# 17092    r1i1p1f1     Omon          so         gn
# 17211    r1i1p1f1     Omon          so         gn
#
#                                                   zstore  dcpp_init_year
# 165    gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 323    gs://cmip6/CMIP/BCC/BCC-CSM2-MR/historical/r1i...             NaN
# 586    gs://cmip6/CMIP/BCC/BCC-ESM1/historical/r1i1p1...             NaN
# 838    gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/historical/r1...             NaN
# 903    gs://cmip6/CMIP/CAS/FGOALS-f3-L/historical/r1i...             NaN
# 1455   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 4476   gs://cmip6/CMIP/CNRM-CERFACS/CNRM-CM6-1/histor...             NaN
# 5411   gs://cmip6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/histo...             NaN
# 5755   gs://cmip6/CMIP/E3SM-Project/E3SM-1-0/historic...             NaN
# 6030   gs://cmip6/CMIP/EC-Earth-Consortium/EC-Earth3-...             NaN
# 6540   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9246   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r1...             NaN
# 9540   gs://cmip6/CMIP/MIROC/MIROC6/historical/r10i1p...             NaN
# 10200  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/historica...             NaN
# 10498  gs://cmip6/CMIP/MOHC/UKESM1-0-LL/historical/r1...             NaN
# 11493  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G-CC/histo...             NaN
# 11683  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/historic...             NaN
# 11747  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/historic...             NaN
# 12593  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-H/historic...             NaN
# 13382  gs://cmip6/CMIP/NCAR/CESM2-WACCM/historical/r1...             NaN
# 14236  gs://cmip6/CMIP/NCAR/CESM2/historical/r10i1p1f...             NaN
# 14237  gs://cmip6/CMIP/NCAR/CESM2/historical/r10i1p1f...             NaN
# 14412  gs://cmip6/CMIP/NCAR/CESM2/historical/r11i1p1f...             NaN
# 14413  gs://cmip6/CMIP/NCAR/CESM2/historical/r11i1p1f...             NaN
# 14577  gs://cmip6/CMIP/NCAR/CESM2/historical/r1i1p1f1...             NaN
# 14578  gs://cmip6/CMIP/NCAR/CESM2/historical/r1i1p1f1...             NaN
# 14742  gs://cmip6/CMIP/NCAR/CESM2/historical/r2i1p1f1...             NaN
# 14743  gs://cmip6/CMIP/NCAR/CESM2/historical/r2i1p1f1...             NaN
# 14907  gs://cmip6/CMIP/NCAR/CESM2/historical/r3i1p1f1...             NaN
# 14908  gs://cmip6/CMIP/NCAR/CESM2/historical/r3i1p1f1...             NaN
# 15072  gs://cmip6/CMIP/NCAR/CESM2/historical/r4i1p1f1...             NaN
# 15073  gs://cmip6/CMIP/NCAR/CESM2/historical/r4i1p1f1...             NaN
# 15236  gs://cmip6/CMIP/NCAR/CESM2/historical/r5i1p1f1...             NaN
# 15237  gs://cmip6/CMIP/NCAR/CESM2/historical/r5i1p1f1...             NaN
# 15401  gs://cmip6/CMIP/NCAR/CESM2/historical/r6i1p1f1...             NaN
# 15402  gs://cmip6/CMIP/NCAR/CESM2/historical/r6i1p1f1...             NaN
# 15565  gs://cmip6/CMIP/NCAR/CESM2/historical/r7i1p1f1...             NaN
# 15566  gs://cmip6/CMIP/NCAR/CESM2/historical/r7i1p1f1...             NaN
# 15729  gs://cmip6/CMIP/NCAR/CESM2/historical/r8i1p1f1...             NaN
# 15730  gs://cmip6/CMIP/NCAR/CESM2/historical/r8i1p1f1...             NaN
# 15893  gs://cmip6/CMIP/NCAR/CESM2/historical/r9i1p1f1...             NaN
# 15894  gs://cmip6/CMIP/NCAR/CESM2/historical/r9i1p1f1...             NaN
# 16230  gs://cmip6/CMIP/NCC/NorCPM1/historical/r24i1p1...             NaN
# 16515  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/historical/...             NaN
# 16516  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/historical/...             NaN
# 16696  gs://cmip6/CMIP/NOAA-GFDL/GFDL-ESM4/historical...             NaN
# 16697  gs://cmip6/CMIP/NOAA-GFDL/GFDL-ESM4/historical...             NaN
# 16837  gs://cmip6/CMIP/NUIST/NESM3/historical/r1i1p1f...             NaN
# 17092  gs://cmip6/CMIP/SNU/SAM0-UNICON/historical/r1i...             NaN
# 17211  gs://cmip6/CMIP/UA/MCM-UA-1-0/historical/r1i1p...             NaN
